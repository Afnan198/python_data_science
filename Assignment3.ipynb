# %% [markdown]
# ## Q: Write a simple program to determine if a given year is a leap year using user input

# %%
year=int(input("Enter a year:"))
print(year)
if (year%4==0 and year%100!=0) or (year%4==0):
    print("Year is leap year")
else:
    print("Year is not leap year")
# Out:
# Enter a year: 2016
# 2016
# Year is leap year
