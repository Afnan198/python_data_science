# %% [markdown]
# ## LIST

# %%
lst=['math','chemistry',100,100.1]
type(lst)
a=len(lst)
print(a)
print(lst)
lst.append('afnan')
print(lst)
lst.append(['afnan','juthika'])
lst
lst.insert(3,'jaaan')
lst
lst.extend(['abbu','ammu'])
lst
# Out:
# 4
# ['math', 'chemistry', 100, 100.1]
# ['math', 'chemistry', 100, 100.1, 'afnan']
# ['math',
#  'chemistry',
#  100,
#  'jaaan',
#  100.1,
#  'afnan',
#  ['afnan', 'juthika'],
#  'abbu',
#  'ammu']

# %%
b=[1,2,3,4]
sum(b)
# Out:
# 10
