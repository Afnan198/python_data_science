# %% [markdown]
# # Comment

# %%
# HI.you can comment like this

# %%
'''
Hi I am Afnan
you can comment like this also
'''
# Out:
# '\nHi I am Afnan\nyou can comment like this also\n'

# %% [markdown]
# # Datatype

# %% [markdown]
# ## Numbers

# %%
1+1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
6/3
# Out:
# 2.0

# %%
6%3
# Out:
# 0

# %%
6%5
# Out:
# 1

# %%
# for some number to the power something(x^y)

# %%
# 5^2=25
5**2
# Out:
# 25

# %%
#now if we string like this
10 * 'i love you '
# Out:
# 'i love you i love you i love you i love you i love you i love you i love you i love you i love you i love you '

# %%
# if you want to know the type of anything!!
type(2)
# Out:
# int

# %%
type('afnan')
# Out:
# str

# %%
type(0.3)
# Out:
# float

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Strings

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Hello'
# Out:
# 'Hello'

# %% [markdown]
# # Variable Assignment

# %%
a=10
b='juthika '
a*b
# Out:
# 'juthika juthika juthika juthika juthika juthika juthika juthika juthika juthika '

# %% [markdown]
# ## Print

# %%
first_name='Afnan'
last_name='Diganta'

# %%
print("My first name is {} and last name is {} ".format(first_name, last_name))
# Out:
# My first name is Afnan and last name is Diganta

# %%
print("My first name is {} and last name is {} ".format(last_name, first_name))
# Out:
# My first name is Diganta and last name is Afnan

# %%
print("My first name is {a} and last name is {b} ".format(a=last_name, b=first_name))
# Out:
# My first name is Diganta and last name is Afnan

# %%
print("My first name is {a} and last name is {b} ".format(a=first_name, b=last_name))
# Out:
# My first name is Afnan and last name is Diganta

# %%
# counting character
len('Afnan ')
# Out:
# 6
