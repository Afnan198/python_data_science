# %% [markdown]
# ## Input function

# %% [markdown]
# ###### it reads the input as a string and return it

# %%
a=input("Enter your name:")
print(a)
# Out:
# Enter your name: Dig
# Dig

# %% [markdown]
# ###### as input func take input as str so b+c=34

# %%
b=input("First Number: ")
c=input("Second Number: ")
print(b+c)
# Out:
# First Number:  3
# Second Number:  4
# 34

# %%
print(int(b)+int(c))
# Out:
# 7
