# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\h\anaconda3\lib\site-packages (2.3.5)

# %%
import numpy as np

# %%
list1=[1,2,3]
print(list1)
# Out:
# [1, 2, 3]

# %%
arr_list1=np.array(list1)
print(arr_list1)
print(arr_list1.ndim)
# Out:
# [1 2 3]
# 1

# %%
list1=[1,2,3]
list2=[4,5,6]
arr_list2=np.array([list1, list2])
print(arr_list2)
print(arr_list2.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2

# %%
list1=[1,2,3]
list2=[4,5,6]
list3=[7,8,9]
arr_list3=np.array([[list1,list2,list3]])
print(arr_list3)
print(arr_list3.ndim)
# Out:
# [[[1 2 3]
#   [4 5 6]]]
# 3
