# %% [markdown]
# ## Assignment 1

# %% [markdown]
# ### Q1:Write python programme that prints - "Quotes" and single 'quotes' are tircky.

# %%
print('''"quotes" and single 'quotes' are tricky.''')
# Out:
# "quotes" and single 'quotes' are tricky.

# %%
### Q2:For a business create 3 variables to store , name, age, city. then print a sentence that uses this variables

# %%
name='Digonto'
age=24
city='Dhaka'
print("my name is ",name,". I am ",age,"years old. And I live in",city)
# Out:
# my name is  Digonto . I am  24 years old. And I live in Dhaka
