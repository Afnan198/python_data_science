# %% [markdown]
# ## Assignment 2

# %% [markdown]
# #### Q1: Write a python program to input student name and marks of 3 subjects.Pirnt name and percentage in output

# %%
name=input("Enter your  name: ")
mark1=input("Math:")
mark2=input("Physics:")
mark3=input("Chemistry:")
print(name)
percentage=((int(mark1)+int(mark2)+int(mark3))/300)*100
print("Yours percentage is:",float(percentage),"%")
# Out:
# Enter your  name:  Afnan
# Math: 44
# Physics: 56
# Chemistry: 55
# Afnan
# Yours percentage is: 51.66666666666667 %
